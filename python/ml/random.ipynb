# %%
# 使用PCA进行降噪

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
X = np.random.uniform(0, 100, size=100)
Y = np.random.normal(0, 100, 100)
test_x = np.linspace(0, 100, 100)

# %%
plt.plot(test_x, X)
plt.plot(test_x, Y, color='r')
